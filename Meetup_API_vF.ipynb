# %%
# Import required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

pd.options.mode.chained_assignment = None  # default='warn'
import random

import meetup.api
import requests
import json
import time

# %% [markdown]
# Note: Group member count data is updated regularly and therefore will not tie to the member data unless updated together. There are also some members who are private and therefore will not have their information included which explains why certain totals (particularly in large meetups) will still not match.

# %%
# Add Meetup key and access API client
api_key = 'YOUR_API_KEY'
client = meetup.api.Client(api_key)
type(client)
# Out:
# meetup.api.Client

# %%
# Create function which creates list of London Technology meetups
# Meetup group criteria embedded in the API call
# Functionality is also built in to sleep in order to respect rate limits as Meetup API has variable rate limits
def create_group_df(n_groups):
    group_df = pd.DataFrame([])
    i = 0

    while i < n_groups:
        json_groups = requests.get(
            'https://api.meetup.com/find/groups?&sign=true&photo-host=public&country=GB&location=London&category=34&key={}&offset={}'.format(api_key,str(i)))
        group_df_dict = json_groups.json()
        temp_group_df = pd.DataFrame.from_dict(group_df_dict)
        group_df = pd.concat([group_df,temp_group_df],sort=False)
        i += 1

        print('----------Request {}----------'.format(i))
        print('Status: ',json_groups)
        print('X-RateLimit-Remaining: ',json_groups.headers['X-RateLimit-Remaining'])

        if int(json_groups.headers['X-RateLimit-Remaining']) == 5:
            time.sleep(int(json_groups.headers['X-RateLimit-Reset'])+5)

    group_df.reset_index(drop=True,inplace=True)
    return group_df

# %%
# Create desired number of groups
group_df = create_group_df(50)

# Remove groups with less than 50 members
group_df = group_df[group_df['members']>50]
group_df.reset_index(drop=True,inplace=True)

# %%
# Export group csv
group_df.to_csv('group_list.csv', index=False)

# %%
# Load prior member and group data (if revisiting this later)
#group_df = pd.read_csv('group_list.csv')
#member_df = pd.read_csv('member_list.csv')

# %%
# Select subset of groups of interest and only columns of interest which will be used to get members
sub_group_df = group_df[['name','urlname','id','members']].iloc[1301:1531]

# Alternatively can select groups which contain certain string in name (e.g. Python)
#sub_group_df = group_df[['name','urlname','id','members']].loc[group_df['name'].str.contains('Py')]
#group_df[['name','urlname','id','members']].iloc[:15]
print("Total Members: ",sub_group_df['members'].sum())
sub_group_df
# Out:
# Total Members:  175617
#                                                    name  \
# 1301                                         Vim London
# 1302                                       London NoSQL
# 1303                                       HackHumanity
# 1304                                 London Riak Meetup
# 1305           Learn How to Make an App (iOS & Android)
# 1306                               Big WP Meetup London
# 1307   InsTech London - The Insurance Technology Meetup
# 1308                      Big Data Developers in London
# 1309                          RegTech - Capital Markets
# 1310                   Unofficial MuleSoft London Group
# 1311                                            LondonR
# 1312              Argyll Scott London Technology Meetup
# 1313                        Polish Developers in London
# 1314                                          DroneZone
# 1315                                   Learn Python Now
# 1316                                   Bitcoin Startups
# 1317                                         BDD London
# 1318                          UK Computer Vision Meetup
# 1319                   IoT, IoE & WearableTech - London
# 1320                        Data Science Network London
# 1321       FrenchLAB Community - Incubateur francophone
# 1322                         Lotico London Semantic Web
# 1323                               edX London Community
# 1324                                       Kingdom Code
# 1325       London SQL Meetup for Database professionals
# 1326                         London Magento Users Group
# 1327                                         PWA London
# 1328                              Dennis Digital DropIn
# 1329                             London Drupal Pub Meet
# 1330                                         London Web
# ...                                                 ...
# 1501                                    London Octocats
# 1502                                  Reactivate London
# 1503                                         Mobile Web
# 1504                             Testing Academy Meetup
# 1505                     Herzum Atlassian Meetup London
# 1506                                Vaadin London Group
# 1507       London Conscious Design & Engineering Meetup
# 1508                                        Lucee Group
# 1509                            Make Money Online Smart
# 1510                                 Functional Finance
# 1511    Data Science & Business Analytics London Meetup
# 1512                          London Synthesizer Meetup
# 1513                      London Creative Coding Meetup
# 1514                         London Startup Founder 101
# 1515                                   Code Crew London
# 1516                        Freelancers and freespirits
# 1517                 Hands-on Big data science workshop
# 1518                       London Startup Growth Meetup
# 1519                       London Emerging Technologies
# 1520                London Social Professionals Network
# 1521  Mapping open data to unlock new insights. Lond...
# 1522                                 Chelsea Apps Talks
# 1523                              Jenkins Online Meetup
# 1524  MiSK Hackathon London: Hack for Health, $20k P...
# 1525                        Agile for Agencies - London
# 1526                                KNIME User Group UK
# 1527                   London Engineers^Artists Meet-up
# 1528       Mixed Reality Experience Playground - London
# 1529                           Scale Warriors of London
# 1530                    London Amazon CloudSearch Group
#
#                                             urlname        id  members
# 1301                                     Vim-London   5431952      503
# 1302                      London-NoSQL-and-Big-Data  12962072     1126
# 1303                                   HackHumanity  12347062      233
# 1304                                    riak-london   3738932      402
# 1305                                      makeanapp  16147842     2312
# 1306   Big-Media-Enterprise-WordPress-London-Meetup  12502532      355
# 1307                                        instech  18527736     2263
# 1308                  Big-Data-Developers-in-London   9516272     7189
# 1309                                        RegTech  21830689      452
# 1310                         MuleSoft-Meetup-London  16649782       55
# 1311                                        LondonR   1594526     3227
# 1312    Argyll-Scott-London-Technology-Meetup-Group  19853637      375
# 1313                    Polish-Developers-in-London  12070462      369
# 1314                                      DroneZone   4041782      261
# 1315                 London-Autodidacts-Programming  18527929     1317
# 1316                               Bitcoin-Startups   9311982      390
# 1317                                      BDDLondon   2991792     1342
# 1318                      UK-Computer-Vision-Meetup  18214876      396
# 1319                             WearableTechLondon  17622502     1241
# 1320                       datasciencenetworklondon  19944387      886
# 1321                                      frenchlab  19853109      333
# 1322                                  LondonSWGroup   1462944      494
# 1323                           edX-London-Community   5710792      319
# 1324                                   Kingdom-Code  14894802       69
# 1325                              London-SQL-Meetup  14849742      721
# 1326                                 magento-london   1582377     1756
# 1327                                      PWALondon  19460680      353
# 1328                            DennisDigitalDropIn  13187962      169
# 1329                         London-Drupal-Pub-Meet   1521989     1053
# 1330                                      londonweb    163876     4693
# ...                                             ...       ...      ...
# 1501                                London-Octocats  19421135       72
# 1502                              Reactivate-London  21037779     1137
# 1503                                     mobile_web   3837332      478
# 1504                         Testing-Academy-Meetup  19936191       75
# 1505                 Herzum-Atlassian-Meetup-London  18677015      125
# 1506                            Vaadin-London-Group  18557376      103
# 1507     London-Conscious-Design-Engineering-Meetup  19743964      174
# 1508                                    Lucee-Group   9720222      108
# 1509                        make-money-online-smart  29349905       89
# 1510                             Functional-Finance  16340792      181
# 1511  Data-Science-Business-Analytics-London-Meetup  15981352      602
# 1512                            London-Synth-Meetup  17854312      563
# 1513                         london-creative-coding  10625522     1055
# 1514                     London-Startup-Founder-101   9680462     6351
# 1515                                    codecrewldn  11268532      421
# 1516                                londoncoworking   4197102      708
# 1517             Hands-on-Big-data-science-workshop  18235566      613
# 1518                   London-Startup-Growth-Meetup  19963718     3146
# 1519                     LondonEmergingTechnologies  17392612      166
# 1520            London-Social-Professionals-Network  10173512     1209
# 1521       mapping-open-data-to-unlock-new-insights  14991272      528
# 1522                             Chelsea-Apps-Talks  17455502      371
# 1523                          Jenkins-online-meetup  19663277     2753
# 1524                                 MiSK-Hackathon  20926082      103
# 1525                               agileforagencies  16362092      792
# 1526                            KNIME-User-Group-UK  11281982      356
# 1527                London-Engineers-Artists-Meetup  19339436      142
# 1528     Mixed-Reality-Experience-Playground-London  26283653      196
# 1529                       Scale-Warriors-of-London  16212172       80
# 1530                London-Amazon-CloudSearch-Group   8207722       76
#
# [230 rows x 4 columns]

# %%
# Create function which queries API for members of a certain group by batch of up to 200
# Functionality is also built in to sleep in order to respect rate limits as Meetup API has variable rate limits
def create_member_df(group_id):
    member_df = pd.DataFrame([])
    i = 0
    number_of_requests = np.ceil(group_df['members'].loc[group_df['id'] == group_id] / 200).values
    
    while i < number_of_requests:
        try:
            json_members = requests.get('https://api.meetup.com/2/members?group_id={}&key={}&offset={}'.format(str(group_id), api_key,str(i)))
            member_df_dict = json_members.json()
            temp_member_df = pd.DataFrame.from_dict(member_df_dict['results'])
            member_df = pd.concat([member_df,temp_member_df],sort=False)
            i += 1

            print('----------Request {}----------'.format(i))
            print('Status: ',json_members)
            print('X-RateLimit-Remaining: ',json_members.headers['X-RateLimit-Remaining'])

            if int(json_members.headers['X-RateLimit-Remaining']) == 5:
                time.sleep(int(json_members.headers['X-RateLimit-Reset'])+5)
            member_df.reset_index(drop=True,inplace=True)
        except:
            i += 1

    return member_df

# %%
member_df = pd.DataFrame([])

# Run member function for all groups in subgroup and create dataframe out of members
for group_id in sub_group_df['id']:
    try:
        temp_member_df = create_member_df(group_id)
        temp_member_df['group_name'] = sub_group_df['urlname'].loc[sub_group_df['id'] == group_id].item()
        member_df = pd.concat([member_df,temp_member_df],sort=False)
    except:
        continue
# Out:
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 13----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 14----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 15----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 16----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 17----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 18----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 19----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 20----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 21----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 22----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 23----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 24----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 25----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 26----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 27----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 28----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 29----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 30----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 31----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 32----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 33----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 34----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 35----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 36----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 13----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 14----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 15----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 16----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 17----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 13----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 14----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 15----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 16----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 17----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 18----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 19----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 20----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 21----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 22----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 23----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 24----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 13----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 13----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 14----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 15----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 16----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  21
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  20
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  19
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 13----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 14----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 15----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 16----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 17----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 18----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 19----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 20----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 21----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 22----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 23----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 24----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 25----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 26----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 27----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 28----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 29----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 30----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 31----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 32----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 33----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  21
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  21
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  20
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 13----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 14----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 15----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 16----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 17----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 18----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 19----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 20----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 21----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 22----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  21
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  20
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  19
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  18
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  17
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 8----------
# Status:  <Response [200]>
# ...
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 13----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 14----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  22
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 13----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 14----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 15----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 16----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 17----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 18----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 19----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 20----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 21----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 22----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 23----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 24----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 25----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 26----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 27----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 28----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 29----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 30----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 31----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 32----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 13----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 14----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 15----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 16----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 5----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 6----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 7----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 8----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 9----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 10----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 11----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 12----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 13----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 14----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 3----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28
# ----------Request 4----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  27
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  26
# ----------Request 2----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  25
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  24
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  23
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  29
# ----------Request 1----------
# Status:  <Response [200]>
# X-RateLimit-Remaining:  28

# %%
# Spot check total number of members in subset of groups and number of members in certain groups 
print("Total Members :",len(member_df))
member_df['group_name'].value_counts()
# Out:
# Total Members : 170591
# Big-Data-Developers-in-London                             7193
# DevOps-Exchange-London                                    6590
# London-Startup-Founder-101                                6363
# londonweb                                                 4687
# ln-enterprise-tech                                        4264
# agiletesting                                              4083
# geekpub                                                   3286
# LondonR                                                   3228
# London-Startup-Growth-Meetup                              3137
# Creative-Class                                            3006
# Jenkins-online-meetup                                     2756
# Python-for-Quant-Finance-London                           2675
# AppliedAI                                                 2558
# Data-Natives-London                                       2553
# UX-Playground-The-User-Experience-Meetup-for-Londoners    2372
# makeanapp                                                 2312
# instech                                                   2267
# DataTech                                                  2114
# vrlondon                                                  2046
# AND_Chat                                                  1972
# Cassandra-London                                          1851
# magento-london                                            1759
# GraphQL-London                                            1620
# Openstack-London                                          1618
# PyLadiesLondon                                            1613
# London-MongoDB-User-Group                                 1609
# Disrupting-Legal-Industry                                 1547
# Lean-UX-London                                            1431
# BDDLondon                                                 1341
# London-Autodidacts-Programming                            1318
#                                                           ...
# Technology-for-Property                                    134
# CloudStack-European-User-Group                             133
# Herzum-Atlassian-Meetup-London                             125
# Agile-Government-UK                                        119
# craftcmsLDN                                                113
# Agile-Mentorship-Programme                                 112
# Lucee-Group                                                108
# magic-leap-london                                          107
# The-Value-Driven-Product-Owner                             107
# Vaadin-London-Group                                        105
# MiSK-Hackathon                                             103
# Agile-Angel                                                 97
# make-money-online-smart                                     90
# Finastra-Fintech-Makers-London                              85
# Scale-Warriors-of-London                                    80
# Aging2london                                                78
# London-Amazon-CloudSearch-Group                             76
# Testing-Academy-Meetup                                      75
# learntocodebrixton                                          75
# London-QlikView-Developers-Group                            72
# London-Octocats                                             72
# London-Wearable-Developers-Meetup                           70
# Kingdom-Code                                                69
# London-VoIP-User-Group-LVUG                                 68
# EEMeetup                                                    68
# sutherlandlabs                                              65
# Arrows-Group-Tech-Events                                    62
# Bioinformatics-Biotechnology-ThinkTank                      62
# MuleSoft-Meetup-London                                      55
# Blockchain-for-Space                                        52
# Name: group_name, Length: 220, dtype: int64

# %%
# Create member list dataframe
member_df.to_csv('1301-1531_member_list.csv', index=False)

# %%
# Retrieve missing group names (some groups are private) and ensure it satisfactory
set1 = set(list(group_df['urlname'].iloc[1301:1531].sort_values(ascending=False)))
set2 = set(list(member_df['group_name'].value_counts().index))
set1.symmetric_difference(set2)
# Out:
# {'BudEvents',
#  'Cpp-London-Developers',
#  'Digital-Adventure-Club',
#  'Enterprise-UX-London',
#  'Financial-Engineers-Quants-London',
#  'London-CRM-Meetup',
#  'London-Engineers-Artists-Meetup',
#  'RegTech',
#  'london-seo-ppc',
#  'werinnovation'}
